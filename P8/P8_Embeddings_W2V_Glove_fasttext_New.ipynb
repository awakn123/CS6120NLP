# %% [markdown]
# ## This is a starter program for training and apply word embeddings

# %%
# -----------------------------------------------------------------
# Import text8 file, which is the first 100MB of the English Wikipedia.
# The file is available at   https://www.kaggle.com/datasets/includelgc/word2vectext8
# The file is already downloaded and saved in the folder text8 Wikipedia.
# The file is a single line of text with 17,005,207 words and 100,000,000 characters.
# The file is read and the first 1,000,000 characters are read and stored in the variable text.
# The text is split into words and the punctuation is removed.
# -----------------------------------------------------------------



import numpy as np
import tensorflow as tf
import time
# put a time stamp with hour, min, sec
print(time.strftime("%H:%M:%S", time.gmtime()))


# filename = './text8'
filename = './reviews_Video_Games_5.json'

def read_data(filename, char):
    with open(filename, 'r') as f:
        data = f.read(char)
    return data


text = read_data(filename, 1000000)

print(time.strftime("%H:%M:%S", time.gmtime()))

len(text)

print(time.strftime("%H:%M:%S", time.gmtime()))

# split the text into words
words = text.split()
len(words)
print(time.strftime("%H:%M:%S", time.gmtime()))

# remove the punctuation
import string
table = str.maketrans('', '', string.punctuation)
words = [w.translate(table) for w in words]
print(len(words))
print(time.strftime("%H:%M:%S", time.gmtime()))
print(words)
# Out:
# 21:52:03
# 21:52:03
# 21:52:03
# 21:52:03
# 165805
# 21:52:03
# ['reviewerID', 'A2HD75EMZR8QLN', 'asin', '0700099867', 'reviewerName', '123', 'helpful', '8', '12', 'reviewText', 'Installing', 'the', 'game', 'was', 'a', 'struggle', 'because', 'of', 'games', 'for', 'windows', 'live', 'bugsSome', 'championship', 'races', 'and', 'cars', 'can', 'only', 'be', 'unlocked', 'by', 'buying', 'them', 'as', 'an', 'addon', 'to', 'the', 'game', 'I', 'paid', 'nearly', '30', 'dollars', 'when', 'the', 'game', 'was', 'new', 'I', 'dont', 'like', 'the', 'idea', 'that', 'I', 'have', 'to', 'keep', 'paying', 'to', 'keep', 'playingI', 'noticed', 'no', 'improvement', 'in', 'the', 'physics', 'or', 'graphics', 'compared', 'to', 'Dirt', '2I', 'tossed', 'it', 'in', 'the', 'garbage', 'and', 'vowed', 'never', 'to', 'buy', 'another', 'codemasters', 'game', 'Im', 'really', 'tired', 'of', 'arcade', 'style', 'rallyracing', 'games', 'anywayIll', 'continue', 'to', 'get', 'my', 'fix', 'from', 'Richard', 'Burns', 'Rally', 'and', 'you', 'should', 'to', 'httpwwwamazoncomRichardBurnsRallyPCdpB000C97156refsr11ieUTF8qid1341886844sr81keywordsrichardburnsrallyThank', 'you', 'for', 'reading', 'my', 'review', 'If', 'you', 'enjoyed', 'it', 'be', 'sure', 'to', 'rate', 'it', 'as', 'helpful', 'overall', '10', 'summary', 'Pay', 'to', 'unlock', 'content', 'I', 'dont', 'think', 'so', 'unixReviewTime', '1341792000', 'reviewTime', '07', '9', '2012', 'reviewerID', 'A3UR8NLLY1ZHCX', 'asin', '0700099867', 'reviewerName', 'Alejandro', 'Henao', 'Electronic', 'Junky', 'helpful', '0', '0', 'reviewText', 'If', 'you', 'like', 'rally', 'cars', 'get', 'this', 'game', 'you', 'will', 'have', 'funIt', 'is', 'more', 'oriented', 'to', '34European', 'market34', 'since', 'here', 'in', 'America', 'there', 'isnt', 'a', 'huge', 'rally', 'fan', 'party', 'Music', 'it', 'is', 'very', 'European', 'and', 'even', 'the', 'voices', 'from', 'the', 'game', 'very', '34English34', 'accentThe', 'multiplayer', 'isnt', 'the', 'best', 'but', 'it', 'works', 'just', 'ok', 'overall', '40', 'summary', 'Good', 'rally', 'game', 'unixReviewTime', '1372550400', 'reviewTime', '06', '30', '2013', 'reviewerID', 'A1INA0F5CWW3J4', 'asin', '0700099867', 'reviewerName', 'Amazon', 'Shopper', 'MrRepsol', 'helpful', '0', '0', 'reviewText', '1st', 'shipment', 'received', 'a', 'book', 'instead', 'of', 'the', 'game2nd', 'shipment', 'got', 'a', 'FAKE', 'one', 'Game', 'arrived', 'with', 'a', 'wrong', 'key', 'inside', 'on', 'sealed', 'box', 'I', 'got', 'in', 'contact', 'with', 'codemasters', 'and', 'send', 'them', 'pictures', 'of', 'the', 'DVD', 'and', 'the', 'content', 'They', 'said', 'nothing', 'they', 'can', 'do', 'its', 'a', 'fake', 'DVDReturned', 'it', 'good', 'bye', 'overall', '10', 'summary', 'Wrong', 'key', 'unixReviewTime', '1403913600', 'reviewTime', '06', '28', '2014', 'reviewerID', 'A1DLMTOTHQ4AST', 'asin', '0700099867', 'reviewerName', 'ampgreen', 'helpful', '7', '10', 'reviewText', 'I', 'got', 'this', 'version', 'instead', 'of', 'the', 'PS3', 'version', 'which', 'turned', 'out', 'to', 'be', 'a', 'mistake', 'Console', 'versions', 'of', 'games', 'look', '95', 'percent', 'as', 'good', 'as', 'their', 'PC', 'versions', 'but', 'you', 'do', 'not', 'have', 'to', 'deal', 'with', 'driver', 'issues', 'and', 'the', 'numerous', 'things', 'that', 'can', 'go', 'wrong', 'with', 'windows', 'First', 'off', 'the', 'installation', 'takes', 'about', '30', 'minutes', 'which', 'is', 'ridiculous', 'I', 'have', 'never', 'had', 'a', 'game', 'take', 'this', 'long', 'to', 'load', 'Shift', '2', 'took', 'about', '20', 'minutes', 'which', 'seemed', 'too', 'long', 'also', 'Next', 'many', 'of', 'the', 'latest', 'games', 'for', 'PC', 'are', 'forcing', 'you', 'to', 'have', 'an', 'internet', 'connection', 'in', 'order', 'to', 'install', 'the', 'game', 'regardless', 'of', 'whether', 'you', 'want', 'to', 'play', 'only', 'offline', 'single', 'player', 'games', 'Shift', '2', 'unleashed', 'is', 'also', 'like', 'this', 'so', 'be', 'forewarned', 'Internet', 'requirements', 'are', 'not', 'prominently', 'displayed', 'on', 'the', 'boxes' ...

# %%
# -----------------------------------------------------------------
# Preprocessing the text
# remove the non-alphabetic tokens
# convert the words to lower case
# remove the stop words
# remove the short words
# count the frequency of each word
# remove the words that appear only once
# create a vocabulary
# create a dictionary to convert words to integers
# -----------------------------------------------------------------



print(time.strftime("%H:%M:%S", time.gmtime()))

# remove the non-alphabetic tokens
words = [word for word in words if word.isalpha()]
print("step 1", len(words))

print(time.strftime("%H:%M:%S", time.gmtime()))


# convert the words to lower case
words = [word.lower() for word in words]
print("step 2", len(words))

print(time.strftime("%H:%M:%S", time.gmtime()))

# remove the stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

words = [word for word in words if word not in stop_words]
print("step 3", len(words))
print(time.strftime("%H:%M:%S", time.gmtime()))


# # remove the short words
# words = [word for word in words if len(word) > 1]
# print("step 4", len(words))

# print(time.strftime("%H:%M:%S", time.gmtime()))

# count the frequency of each word
from collections import Counter
word_freq = Counter(words)
print("step 5", len(word_freq))

print(time.strftime("%H:%M:%S", time.gmtime()))

# remove the words that appear only once
words = [word for word in words if word_freq[word] > 1]
print("step 6", len(words))

print(time.strftime("%H:%M:%S", time.gmtime()))

# create a vocabulary
vocab = set(words)
print("step 7", len(vocab))

print(time.strftime("%H:%M:%S", time.gmtime()))


# create a dictionary to convert words to integers
word_to_int = {w: i for i, w in enumerate(vocab)}
print(len(word_to_int))

# convert the words to integers
int_words = [word_to_int[word] for word in words]
print(len(int_words))

# create a dictionary to convert integers to words
int_to_word = {i: w for i, w in enumerate(vocab)}
print(len(int_to_word))

print(time.strftime("%H:%M:%S", time.gmtime()))

# create corpus by converting words to numbers
# Out:
# 21:52:11
# step 1 155335
# 21:52:11
# step 2 155335
# 21:52:11
# step 3 84961
# 21:52:11
# step 5 11896
# 21:52:11
# step 6 78205
# 21:52:11
# step 7 5140
# 21:52:11
# 5140
# 78205
# 5140
# 21:52:11

# %%
# -----------------------------------------------------------------
# Word2Vec is a predictive model that learns to predict the context from the target word.
# The input to the model is a word and the output is the context words.
# The window size is the maximum distance between the target word and the context words.
# The input to the model is a one-hot encoded vector of the target word.
# The output of the model is a probability distribution over the vocabulary.
# The probability distribution is the likelihood of the context words given the target word.
# The model is trained to maximize the likelihood of the context words given the target word (Skip-gram model).
# The model is trained using the negative log likelihood loss function.
# The model is trained using the stochastic gradient descent optimization algorithm.
# The word2vec algorithm is a two-layer neural network.
# -----------------------------------------------------------------


from gensim.models import word2vec

model_cb = word2vec.Word2Vec(sentences=[words],  window = 2 ,epochs = 50, vector_size=300,  min_count=1)

print(time.strftime("%H:%M:%S", time.gmtime()))

# # Optionally save the model
# model.save('word2vec.model_cb')

# print(time.strftime("%H:%M:%S", time.gmtime()))

# # load the model


# model_cb = word2vec.Word2Vec.load('word2vec.model_cb')
print(time.strftime("%H:%M:%S", time.gmtime()))

# # get the word vector for a word
# print(model_cb.wv['diabetes'].shape)

print(time.strftime("%H:%M:%S", time.gmtime()))

# get the most similar words
print(model_cb.wv.most_similar('one', topn=5))

print(time.strftime("%H:%M:%S", time.gmtime()))
# Out:
# 21:52:25
# 21:52:25
# 21:52:25
# [('exactly', 0.9967808723449707), ('made', 0.9964603781700134), ('silicone', 0.9964349269866943), ('cover', 0.9963006973266602), ('best', 0.9957575798034668)]
# 21:52:25

# %%
# print the vocabulary in text file
# len(vocab)
vocab
# Out:
# {'heat',
#  'market',
#  'named',
#  'functions',
#  'fisher',
#  'ward',
#  'teepo',
#  'swinging',
#  'checking',
#  'trying',
#  'hyrule',
#  'remaining',
#  'gold',
#  'argue',
#  'ultimate',
#  'hair',
#  'possible',
#  'constantly',
#  'classic',
#  'row',
#  'time',
#  'drawback',
#  'chamber',
#  'unlock',
#  'anytime',
#  'actually',
#  'hang',
#  'item',
#  'necessity',
#  'owners',
#  'blends',
#  'ended',
#  'knock',
#  'yet',
#  'knew',
#  'screw',
#  'crowbar',
#  'defining',
#  'solved',
#  'raquel',
#  'silo',
#  'important',
#  'tm',
#  'knight',
#  'gotta',
#  'anthony',
#  'tunes',
#  'show',
#  'met',
#  'sacred',
#  'crapthe',
#  'fit',
#  'line',
#  'frustration',
#  'fingers',
#  'involves',
#  'gf',
#  'trex',
#  'asin',
#  'zombies',
#  'uzis',
#  'radio',
#  'satisfy',
#  'mass',
#  'tradition',
#  'mission',
#  'legends',
#  'retrieve',
#  'learning',
#  'allowed',
#  'neo',
#  'nuke',
#  'structures',
#  'wanted',
#  'phantasmagoria',
#  'multitude',
#  'touch',
#  'fiddling',
#  'z',
#  'always',
#  'availablethe',
#  'whenever',
#  'rich',
#  'left',
#  'alter',
#  'todays',
#  'consoles',
#  'deep',
#  'nuts',
#  'petersen',
#  'insanely',
#  'reliving',
#  'rei',
#  'mesmerized',
#  'moderate',
#  'creator',
#  'successfully',
#  'bucks',
#  'complex',
#  'easy',
#  'thirds',
#  'championship',
#  'alert',
#  'bunker',
#  'unforgettable',
#  'vibrant',
#  'power',
#  'publishers',
#  'issues',
#  'v',
#  'wonderfully',
#  'passing',
#  'andrew',
#  'drama',
#  'gamesi',
#  'assortment',
#  'worlds',
#  'mirror',
#  'deoxysdarkrai',
#  'hearts',
#  'jigsaw',
#  'thinks',
#  'purchasing',
#  'gone',
#  'catchy',
#  'playing',
#  'point',
#  'defently',
#  'cuteness',
#  'trust',
#  'bother',
#  'furthermore',
#  'cutscenes',
#  'striking',
#  'rage',
#  'crashes',
#  'commercial',
#  'suck',
#  'ties',
#  'zachary',
#  'jellyfish',
#  'citys',
#  'partsthe',
#  'manage',
#  'advice',
#  'shortcuts',
#  'beutiful',
#  'rushed',
#  'jacobs',
#  'saved',
#  'medallion',
#  'pilots',
#  'ignore',
#  'peels',
#  'thomas',
#  'costume',
#  'easily',
#  'sequel',
#  'ufo',
#  'victim',
#  'another',
#  'seconds',
#  'peak',
#  'flip',
#  'modeled',
#  'bettered',
#  'encountered',
#  'sorry',
#  'alana',
#  'terrific',
#  'micheal',
#  'comfort',
#  'races',
#  'controller',
#  'kkarmo',
#  'suffers',
#  'though',
#  'embarks',
#  'artifact',
#  'refined',
#  'actionrpg',
#  'replay',
#  'elf',
#  'humble',
#  'computers',
#  'focused',
#  'newcomer',
#  'scream',
#  'hearing',
#  'zeldas',
#  'graphic',
#  'limb',
#  'wakes',
#  'capabilities',
#  'wound',
#  'goofy',
#  'offer',
#  'rickard',
#  'located',
#  'eidos',
#  'quotocarina',
#  'hungry',
#  'hammer',
#  'rid',
#  'powerfull',
#  'suffer',
#  'exiting',
#  'field',
#  'preety',
#  'mates',
#  'passed',
#  'chicks',
#  'ginger',
#  'vary',
#  'titles',
#  'kondos',
#  'definitly',
#  'solve',
#  'razorwind',
#  'mountain',
#  'lava',
#  'mayhem',
#  'eyes',
#  'presentation',
#  'scion',
#  'every',
#  'folklore',
#  'iterations',
#  'faulkerson',
#  'paid',
#  'electricity',
#  'thus',
#  'pushes',
#  'delivers',
#  'evolution',
#  'thankfully',
#  'wars',
#  'actors',
#  'staying',
#  'board',
#  'sight',
#  'frustrated',
#  'reviewtime',
#  'reccomend',
#  'insane',
#  'round',
#  'already',
#  'howling',
#  'various',
#  'wanna',
#  'regardless',
#  'drives',
#  'kombat',
#  'seamlessly',
#  'fox',
#  'titanic',
#  'gordan',
#  'allowing',
#  'flashing',
#  'lines',
#  'write',
#  'size',
#  'weakness',
#  'chrono',
#  'sequals',
#  'piloting',
#  'definition',
#  'clank',
#  'chaostheory',
#  'mechanics',
#  'vastly',
#  'quake',
#  'kinds',
#  'theme',
#  'helpful',
#  'exploring',
#  'locate',
#  'bugs',
#  'pretty',
#  'nearly',
#  'vital',
#  'commentary',
#  'find',
#  'raptors',
#  'mediocre',
#  'area',
#  'evolved',
#  'beautifully',
#  'tagteam',
#  'whatever',
#  'airplanes',
#  'overworld',
#  'finger',
#  'direct',
#  'youre',
#  'triggers',
#  'jay',
#  'firsttime',
#  'holes',
#  'shells',
#  'beach',
#  'nitro',
#  'awsome',
#  'dull',
#  'head',
#  'magical',
#  'life',
#  'engage',
#  'greatly',
#  'difference',
#  'stress',
#  'lengthy',
#  'exaggerated',
#  'minutes',
#  'mustbuy',
#  'bells',
#  'bar',
#  'rome',
#  'av',
#  'magic',
#  'mon',
#  'controllers',
#  'running',
#  'tops',
#  'sides',
#  'succeeds',
#  'shields',
#  'months',
#  'vain',
#  'horizontal',
#  'utter',
#  'brain',
#  'reality',
#  'hear',
#  'fame',
#  'nod',
#  'alec',
#  'customize',
#  'lovers',
#  'particularly',
#  'wont',
#  'restart',
#  'test',
#  'unsuspecting',
#  'artillery',
#  'tears',
#  'finishing',
#  'menu',
#  'punch',
#  'fandango',
#  'adventures',
#  'development',
#  'sell',
#  'surprise',
#  'feirce',
#  'agree',
#  'obstacle',
#  'instances',
#  'lacking',
#  'final',
#  'khadija',
#  'height',
#  'hl',
#  'wrestlings',
#  'deal',
#  'fluid',
#  'scottypiper',
#  'chosen',
#  'following',
#  'laughable',
#  'relevant',
#  'killed',
#  'odd',
#  'else',
#  'pacifists',
#  'held',
#  'pc',
#  'copy',
#  'avalanche',
#  'abe',
#  'multiplayer',
#  'couple',
#  'ship',
#  'hopefully',
#  'adventurer',
#  'regret',
#  'orchestral',
#  'monkey',
#  'bases',
#  'chase',
#  'gross',
#  'anymore',
#  'foster',
#  'soundtrack',
#  'pace',
#  'marcus',
#  'tony',
#  'leader',
#  'perhaps',
#  'combatquot',
#  'tekkens',
#  'ballon',
#  'later',
#  'regard',
#  'metroid',
#  'jones',
#  'techno',
#  'riven',
#  'thumb',
#  'collector',
#  'coco',
#  'guarantee',
#  'mask',
#  'unfortunatley',
#  'extent',
#  'adjusting',
#  'majoras',
#  'flipping',
#  'dealer',
#  'sold',
#  'enjoyable',
#  'completely',
#  'stole',
#  'reaching',
#  'puzzlebased',
#  'flamethrower',
#  'tries',
#  'slick',
#  'aku',
#  'phillip',
#  'transpire',
#  'shuttle',
#  'appear',
#  'ravens',
#  'sitting',
#  'shotgun',
#  'sooner',
#  'resolution',
#  'leita',
#  'aonuma',
#  'complaint',
#  'winter',
#  'race',
#  'ledges',
#  'hooked',
#  'reversed',
#  'worn',
#  'tempted',
#  'corruption',
#  'platinum',
#  'till',
#  'levels',
#  'somebody',
#  'nizami',
#  'virtually',
#  'tatooine',
#  'try',
#  'models',
#  'turbo',
#  'immerse',
#  'reviewing',
#  'brothers',
#  'defend',
#  'bottles',
#  'unlike',
#  'saturn',
#  'heavily',
#  'goldeneye',
#  'oblivion',
#  'computer',
#  'force',
#  'drooling',
#  'simulation',
#  'lack',
#  'messages',
#  'dramatic',
#  'least',
#  'dominate',
#  'reviewerid',
#  'credit',
#  'doubts',
#  'gem',
#  'anything',
#  'tunic',
#  'venture',
#  'deserving',
#  'influence',
#  'reviewer',
#  'twilight',
#  'intelligent',
#  'hanging',
#  'standing',
#  'escape',
#  'parents',
#  'signal',
#  'along',
#  'audio',
#  'watery',
#  'pinpoint',
#  'somehow',
#  'protagonist',
#  'children',
#  'top',
#  'endless',
#  'step',
#  'plan',
#  'improvement',
#  'crowd',
#  'damn',
#  'cousin',
#  'believe',
#  'enchanting',
#  'nigh',
#  'awkward',
#  'probably',
#  'guided',
#  'experience',
#  'little',
#  'dn',
#  'made',
#  'certain',
#  'string',
#  'ganons',
#  'quotwhy',
#  'agony',
#  'hoping',
#  'period',
#  'buying',
#  'summons',
#  'treyvelyn',
#  'moms',
#  'infinite',
#  'discs',
#  'fabulous',
#  'related',
#  'sound',
#  'daniel',
#  'total',
#  'morethe',
#  'boomerang',
#  'ending',
#  'ages',
#  'bright',
#  'london',
#  'seem',
#  'equipped',
#  'meter',
#  'dolphin',
#  'incredibly',
#  'nostalgia',
#  'alley',
#  'windows',
#  'chasrat',
#  'terribly',
#  'assumed',
#  'substantial',
#  'increasingly',
#  'continuous',
#  'evil',
#  'gamei',
#  'truth',
#  'tutorial',
#  'advertised',
#  'cheaters',
#  'count',
#  'subtanks',
#  'scenarios',
#  'nicely',
#  'rex',
#  'heavyweight',
#  'die',
#  'supra',
#  'inventory',
#  'colours',
#  'wvbullrider',
#  'ebgames',
#  'goodies',
#  'invisible',
#  'supreme',
#  'sequels',
#  'spins',
#  'arguably',
#  'awhile',
#  'loving',
#  'fails',
#  'points',
#  'polish',
#  'form',
#  'begin',
#  'controls',
#  'acquire',
#  'teh',
#  'focus',
#  'fall',
#  'caches',
#  'article',
#  'ace',
#  'clicking',
#  'recent',
#  'state',
#  'trench',
#  'mostly',
#  'blew',
#  'challenges',
#  'fishs',
#  'aware',
#  'yard',
#  'ryu',
#  'click',
#  'treasures',
#  'whose',
#  'heart',
#  'stealth',
#  'requirements',
#  'teen',
#  'smaller',
#  'still',
#  'falcon',
#  'stretches',
#  'luckily',
#  'cross',
#  'comparing',
#  'wild',
#  'hardcore',
#  'singing',
#  'example',
#  'press',
#  'center',
#  'art',
#  'combine',
#  'control',
#  'nuisance',
#  'unfolds',
#  'unfortunately',
#  'beating',
#  'ganon',
#  'quality',
#  'added',
#  'moo',
#  'tasks',
#  'overthemoon',
#  'earn',
#  'targeted',
#  'duffy',
#  'cockpit',
#  'walker',
#  'code',
#  'disaster',
#  'whistles',
#  'michael',
#  'elaborate',
#  'effects',
#  'pirates',
#  'previously',
#  'advance',
#  'treat',
#  'domain',
#  'getting',
#  'stuck',
#  'criticisms',
#  'span',
#  'percent',
#  'etc',
#  'lasers',
#  'prettiest',
#  'identical',
#  'introduction',
#  'function',
#  'high',
#  'fantsay',
#  'differnt',
#  'steer',
#  'region',
#  'supply',
#  'engine',
#  'screams',
#  'options',
#  'dash',
#  'none',
#  'shin',
#  'la',
#  'cords',
#  'attacking',
#  'patch',
#  'whole',
#  'eventually',
#  'grown',
#  'sages',
#  'told',
#  'praise',
#  'chicken',
#  'love',
#  'girlfriend',
#  'inspiring',
#  'lower',
#  'themthis',
#  'al',
#  'change',
#  'day',
#  'hazard',
#  'exhaust',
#  'maidens',
#  'missions',
#  'royal',
#  'create',
#  'animations',
#  'born',
#  'combo',
#  'pressed',
#  'minigames',
#  'never',
#  'villains',
#  'endthe',
#  'covers',
#  'said',
#  'makers',
#  'xmen',
#  'purrlin',
#  'amazed',
#  'provide',
#  'initially',
#  'r',
#  'rock',
#  'pepole',
#  'fake',
#  'koji',
#  'cakewalk',
#  'pattern',
#  'plug',
#  'versions',
#  'fitting',
#  'monsters',
#  'pilot',
#  'units',
#  'itits',
#  'like',
#  'interest',
#  'spawned',
#  'unwarranted',
#  'energy',
#  'correspond',
#  'manual',
#  'quicker',
#  'individual',
#  'unusual',
#  'eat',
#  'finest',
#  'smoothly',
#  'gasp',
#  'combines',
#  'unless',
#  'stepped',
#  'racetrack',
#  'compete',
#  'rough',
#  'books',
#  'sephiroth',
#  'witches',
#  'satisfaction',
#  'repeat',
#  'wireless',
#  'data',
#  'crawl',
#  'pso',
#  'grandson',
#  'lacked',
#  'existing',
#  'speeds',
#  'offshore',
#  'planes',
#  'extremely',
#  'instance',
#  'allot',
#  'easier',
#  'screen',
#  'naughty',
#  'modes',
#  'starring',
#  'wingmen',
#  'big',
#  'airspeeder',
#  'walls',
#  'dropping',
#  'tooie',
#  'tale',
#  'maimability',
#  'know',
#  'heath',
#  'versa',
#  'completion',
#  'eight',
#  'stolen',
#  'sun',
#  'consistently',
#  'originally',
#  'lightly',
#  'deathmatches',
#  'pack',
#  'arias',
#  'compression',
#  'liking',
#  'relax',
#  'deals',
#  'isnt',
#  'aspects',
#  'aint',
#  'twice',
#  'realtime',
#  'tho',
#  'vertical',
#  'ed',
#  'slam',
#  'silly',
#  'opening',
#  'sadly',
#  'repetitive',
#  'smart',
#  'everyone',
#  'effortlessly',
#  'month',
#  'future',
#  'nowadays',
#  'damage',
#  'cord',
#  'wood',
#  'hardbut',
#  'handicapped',
#  'jong',
#  'thrilled',
#  'almost',
#  'hes',
#  'america',
#  'ooagent',
#  'element',
#  'practically',
#  'music',
#  'gracing',
#  'cool',
#  'close',
#  'creative',
#  'grunts',
#  'title',
#  'arts',
#  'orginal',
#  'goku',
#  'timedifficulty',
#  'retrieves',
#  'diablo',
#  'daddy',
#  'buy',
#  'barkhang',
#  'shark',
#  'nick',
#  'lightning',
#  'elsewhere',
#  'thrown',
#  'pond',
#  'determined',
#  'starman',
#  'wand',
#  'explain',
#  'inconvenient',
#  'modifications',
#  'regularly',
#  'snap',
#  'opposed',
#  'singleplayer',
#  'expands',
#  'shines',
#  'think',
#  'fighters',
#  'ff',
#  'turrets',
#  'opposite',
#  'spinning',
#  'loyal',
#  'hurts',
#  'uses',
#  'invisibility',
#  'amazon',
#  'obscure',
#  'plugs',
#  'infiltrate',
#  'may',
#  'law',
#  'resulted',
#  'score',
#  'balders',
#  'weeks',
#  'crazy',
#  'brought',
#  'went',
#  'studios',
#  'goes',
#  'tall',
#  'wellthe',
#  'myst',
#  'specific',
#  'farm',
#  'wanting',
#  'low',
#  'valley',
#  'horrid',
#  'owen',
#  'crashs',
#  'threw',
#  'stupid',
#  'queen',
#  'miles',
#  'helped',
#  'maze',
#  'ajnrules',
#  'look',
#  'erupts',
#  'action',
#  'bad',
#  'product',
#  'conclusion',
#  'dig',
#  'expressions',
#  'accomplishment',
#  'loz',
#  'garden',
#  'temple',
#  'jumbo',
#  'sf',
#  'half',
#  'versus',
#  'themes',
#  'choice',
#  'objectives',
#  'corners',
#  'truely',
#  'list',
#  'moon',
#  'trilogy',
#  'folly',
#  'craft',
#  'jimmy',
#  'dozens',
#  'nearby',
#  'appealing',
#  'however',
#  'evident',
#  'understood',
#  'save',
#  'defeat',
#  'bust',
#  'statues',
#  'cant',
#  'sneaking',
#  'respective',
#  'loss',
#  'novel',
#  'dawn',
#  'arrive',
#  'riding',
#  'language',
#  'searching',
#  'drags',
#  'legitimate',
#  'termina',
#  'exit',
#  'golden',
#  'alive',
#  'mouse',
#  'port',
#  'personality',
#  'birthday',
#  'finally',
#  'realisticlooking',
#  'broken',
#  'shock',
#  'world',
#  'dan',
#  'happen',
#  'new',
#  'array',
#  'volcano',
#  'double',
#  'annoying',
#  'planet',
#  'glitchy',
#  'joshua',
#  'features',
#  'speeding',
#  'nonsense',
#  'jumps',
#  'balloons',
#  'dying',
#  'defined',
#  'unsettling',
#  'built',
#  'technology',
#  'sculptors',
#  'overlook',
#  'imprisoned',
#  'search',
#  'fond',
#  'billy',
#  ...}

# %%
# list the words in the vocabulary that the model learned
len(model_cb.wv.index_to_key)
model_cb.wv.index_to_key
# Out:
# ['game',
#  'overall',
#  'helpful',
#  'reviewerid',
#  'asin',
#  'summary',
#  'reviewtext',
#  'reviewtime',
#  'unixreviewtime',
#  'reviewername',
#  'one',
#  'games',
#  'time',
#  'like',
#  'get',
#  'great',
#  'play',
#  'good',
#  'best',
#  'fun',
#  'first',
#  'zelda',
#  'graphics',
#  'even',
#  'really',
#  'still',
#  'also',
#  'much',
#  'ever',
#  'dont',
#  'played',
#  'well',
#  'many',
#  'better',
#  'levels',
#  'go',
#  'back',
#  'mario',
#  'would',
#  'way',
#  'characters',
#  'find',
#  'playing',
#  'story',
#  'new',
#  'level',
#  'world',
#  'series',
#  'link',
#  'make',
#  'buy',
#  'lot',
#  'pretty',
#  'music',
#  'nintendo',
#  'never',
#  'raider',
#  'different',
#  'tomb',
#  'little',
#  'gameplay',
#  'around',
#  'thing',
#  'made',
#  'know',
#  'could',
#  'say',
#  'classic',
#  'love',
#  'ocarina',
#  'got',
#  'though',
#  'old',
#  'people',
#  'think',
#  'things',
#  'right',
#  'original',
#  'want',
#  'im',
#  'easy',
#  'years',
#  'hard',
#  'look',
#  'youre',
#  'beat',
#  'take',
#  'use',
#  'long',
#  'every',
#  'cant',
#  'mode',
#  'version',
#  'weapons',
#  'two',
#  'part',
#  'ive',
#  'crash',
#  'see',
#  'must',
#  'since',
#  'awesome',
#  'times',
#  'controls',
#  'bad',
#  'video',
#  'thats',
#  'makes',
#  'sound',
#  'kart',
#  'always',
#  'far',
#  'enough',
#  'playstation',
#  'player',
#  'adventure',
#  'youll',
#  'everything',
#  'save',
#  'perfect',
#  'system',
#  'multiplayer',
#  'feel',
#  'amazing',
#  'end',
#  'super',
#  'used',
#  'give',
#  'cool',
#  'character',
#  'getting',
#  'going',
#  'came',
#  'isnt',
#  'need',
#  'favorite',
#  'enemies',
#  'doesnt',
#  'items',
#  'big',
#  'controller',
#  'almost',
#  'hours',
#  'another',
#  'didnt',
#  'evil',
#  'three',
#  'may',
#  'something',
#  'fan',
#  'worth',
#  'recommend',
#  'keep',
#  'control',
#  'challenging',
#  'without',
#  'race',
#  'later',
#  'racing',
#  'gamecube',
#  'missions',
#  'however',
#  'takes',
#  'last',
#  'theres',
#  'excellent',
#  'goldeneye',
#  'actually',
#  'quite',
#  'day',
#  'place',
#  'gaming',
#  'yet',
#  'legend',
#  'bought',
#  'gets',
#  'fighting',
#  'course',
#  'whole',
#  'battle',
#  'fact',
#  'work',
#  'challenge',
#  'hyrule',
#  'man',
#  'real',
#  'fighter',
#  'wont',
#  'put',
#  'run',
#  'difficult',
#  'life',
#  'come',
#  'reason',
#  'friends',
#  'boring',
#  'sure',
#  'works',
#  'collect',
#  'nice',
#  'found',
#  'nothing',
#  'puzzles',
#  'sword',
#  'star',
#  'least',
#  'help',
#  'huge',
#  'looking',
#  'remember',
#  'probably',
#  'final',
#  'bit',
#  'complete',
#  'dungeon',
#  'done',
#  'fans',
#  'start',
#  'dungeons',
#  'away',
#  'metal',
#  'trying',
#  'goes',
#  'second',
#  'snes',
#  'hit',
#  'review',
#  'boss',
#  'might',
#  'movie',
#  'lara',
#  'computer',
#  'although',
#  'comes',
#  'fire',
#  'maybe',
#  'especially',
#  'along',
#  'next',
#  'single',
#  'fight',
#  'pick',
#  'simple',
#  'try',
#  'twisted',
#  'havent',
#  'enjoy',
#  'definitely',
#  'sometimes',
#  'dark',
#  'main',
#  'past',
#  'storyline',
#  'greatest',
#  'said',
#  'experience',
#  'temple',
#  'action',
#  'moves',
#  'either',
#  'street',
#  'rpg',
#  'red',
#  'bond',
#  'released',
#  'cars',
#  'young',
#  'side',
#  'person',
#  'plot',
#  'anyone',
#  'took',
#  'problem',
#  'wasnt',
#  'pc',
#  'choose',
#  'combat',
#  'kind',
#  'special',
#  'beautiful',
#  'already',
#  'set',
#  'able',
#  'players',
#  'short',
#  'sequel',
#  'tekken',
#  'collection',
#  'days',
#  'thought',
#  'move',
#  'looks',
#  'tracks',
#  'less',
#  'truly',
#  'learn',
#  'four',
#  'money',
#  'started',
#  'stars',
#  'previous',
#  'realistic',
#  'finally',
#  'certain',
#  'anything',
#  'true',
#  'wrestling',
#  'making',
#  'open',
#  'banjo',
#  'point',
#  'turok',
#  'water',
#  'value',
#  'absolutely',
#  'bandicoot',
#  'today',
#  'power',
#  'difficulty',
#  'gamers',
#  'secret',
#  'arent',
#  'golden',
#  'let',
#  'small',
#  'etc',
#  'loved',
#  'simply',
#  'several',
#  'fantasy',
#  'enemy',
#  'mask',
#  'order',
#  'using',
#  'interesting',
#  'others',
#  'top',
#  'quest',
#  'mega',
#  'wwf',
#  'mission',
#  'master',
#  'bosses',
#  'seen',
#  'couldnt',
#  'jump',
#  'ii',
#  'effects',
#  'believe',
#  'based',
#  'instead',
#  'everyone',
#  'half',
#  'lost',
#  'turn',
#  'called',
#  'else',
#  'wars',
#  'wouldnt',
#  'problems',
#  'stuff',
#  'forest',
#  'replay',
#  'car',
#  'opinion',
#  'console',
#  'couple',
#  'rare',
#  'speed',
#  'features',
#  'wii',
#  'sounds',
#  'finish',
#  'eye',
#  'fantastic',
#  'shooter',
#  'wonderful',
#  'title',
#  'ill',
#  'guys',
#  'fps',
#  'full',
#  'liked',
#  'become',
#  'feature',
#  'live',
#  'tree',
#  'id',
#  'lots',
#  'youve',
#  'running',
#  'head',
#  'variety',
#  'worlds',
#  'tell',
#  'kazooie',
#  'b',
#  'shooting',
#  'death',
#  'kill',
#  'strategy',
#  'entire',
#  'change',
#  'match',
#  'dirt',
#  'throughout',
#  'annoying',
#  'shoot',
#  'ago',
#  'gold',
#  'solid',
#  'wanted',
#  'seems',
#  'track',
#  'year',
#  'mind',
#  'fast',
#  'places',
#  'design',
#  'james',
#  'face',
#  'titles',
#  'theyre',
#  'genre',
#  'enjoyed',
#  'wrestlers',
#  'modes',
#  'five',
#  'memory',
#  'hidden',
#  'standard',
#  'style',
#  'arcade',
#  'beginning',
#  'highly',
#  'mean',
#  'oh',
#  'legends',
#  'rogue',
#  'rather',
#  'completely',
#  'matter',
#  'screen',
#  'guide',
#  'quality',
#  'ones',
#  'unreal',
#  'basically',
#  'often',
#  'deku',
#  'unique',
#  'fine',
#  'left',
#  'ganondorf',
#  'u',
#  'incredible',
#  'entertaining',
#  'halflife',
#  'adult',
#  'soon',
#  'card',
#  'due',
#  'wrong',
#  'ok',
#  'princess',
#  'stuck',
#  'frustrating',
#  'went',
#  'guess',
#  'unless',
#  'ground',
#  'squadron',
#  'except',
#  'type',
#  'stop',
#  'windows',
#  'parts',
#  'plus',
#  'camera',
#  'machine',
#  'alot',
#  'including',
#  'gamer',
#  'boy',
#  'funny',
#  'add',
#  'breath',
#  'oot',
#  'majoras',
#  'monsters',
#  'unlock',
#  'despite',
#  'idea',
#  'wish',
#  'nearly',
#  'team',
#  'button',
#  'song',
#  'hate',
#  'throw',
#  'age',
#  'unfortunately',
#  'price',
#  'early',
#  'amount',
#  'areas',
#  'figure',
#  'changed',
#  'stages',
#  'extra',
#  'quickly',
#  'online',
#  'plenty',
#  'war',
#  'seem',
#  'area',
#  'engine',
#  'weapon',
#  'given',
#  'beating',
#  'example',
#  'enjoyable',
#  'travel',
#  'croft',
#  'copy',
#  'yes',
#  'city',
#  'cheap',
#  'job',
#  'extremely',
#  'biggest',
#  'notes',
#  'dragon',
#  'banjokazooie',
#  'ai',
#  'perfectly',
#  'crystals',
#  'snowboarding',
#  'case',
#  'dated',
#  'hope',
#  'us',
#  'easily',
#  'gives',
#  'forever',
#  'grand',
#  'explore',
#  'compared',
#  'units',
#  'name',
#  'close',
#  'dead',
#  'defeat',
#  'added',
#  'alert',
#  'impossible',
#  'happy',
#  'flaws',
#  'high',
#  'meet',
#  'deal',
#  'kong',
#  'release',
#  'spent',
#  'worst',
#  'usually',
#  'pieces',
#  'line',
#  'tried',
#  'buying',
#  'minutes',
#  'friend',
#  'together',
#  'controllers',
#  'ship',
#  'longer',
#  'warped',
#  'across',
#  'rest',
#  'ending',
#  'incredibly',
#  'within',
#  'kids',
#  'tough',
#  'history',
#  'puzzle',
#  'looked',
#  'item',
#  'room',
#  'named',
#  'slow',
#  'bring',
#  'coming',
#  'quake',
#  'read',
#  'miss',
#  'means',
#  'light',
#  'epic',
#  'magic',
#  'soundtrack',
#  'kid',
#  'totally',
#  'win',
#  'ganon',
#  'gun',
#  'guy',
#  'secrets',
#  'megaman',
#  'impressive',
#  'quests',
#  'piece',
#  'lives',
#  'months',
#  'decent',
#  'available',
#  'easier',
#  'sort',
#  'lets',
#  'cannot',
#  'cheats',
#  'massive',
#  'various',
#  'jumping',
#  'die',
#  'upon',
#  'progress',
#  'missing',
#  'deep',
#  'begin',
#  'giant',
#  'feels',
#  'okay',
#  'theme',
#  'large',
#  'land',
#  'xbox',
#  'franchise',
#  'house',
#  'turismo',
#  'internet',
#  'important',
#  'cause',
#  'lack',
#  'expect',
#  'six',
#  'late',
#  'hands',
#  'stage',
#  'black',
#  'heart',
#  'unlike',
#  'behind',
#  'memories',
#  'fall',
#  'capcom',
#  'attacks',
#  'turned',
#  'exactly',
#  'guns',
#  'popular',
#  'cut',
#  'leave',
#  'future',
#  'older',
#  'finding',
#  'uka',
#  'wind',
#  'environments',
#  'buttons',
#  'shows',
#  'reviews',
#  'stone',
#  'show',
#  'needed',
#  'near',
#  'castle',
#  'home',
#  'options',
#  'races',
#  'iii',
#  'versions',
#  'possible',
#  'night',
#  'inside',
#  'basic',
#  'stand',
#  'hold',
#  'kinda',
#  'similar',
#  'gran',
#  'sister',
#  'whatever',
#  'break',
#  'tells',
#  'atmosphere',
#  'courses',
#  'gave',
#  'spiritual',
#  'recently',
#  'created',
#  'becomes',
#  'battles',
#  'follow',
#  'mostly',
#  'destroy',
#  'wcw',
#  'ways',
#  'bonus',
#  'exciting',
#  'strong',
#  'told',
#  'zone',
#  'eventually',
#  'mention',
#  'talk',
#  'ask',
#  'hes',
#  'heard',
#  'kept',
#  'turns',
#  'monster',
#  'seriously',
#  'total',
#  'donkey',
#  'harder',
#  'stones',
#  'disc',
#  'number',
#  'form',
#  'cheat',
#  'systems',
#  'entirely',
#  'cortex',
#  'brother',
#  'todays',
#  'c',
#  'disappointed',
#  'amazon',
#  'hear',
#  'child',
#  'honestly',
#  'platform',
#  'stick',
#  'health',
#  'flying',
#  'edition',
#  'blow',
#  'anyway',
#  'rpgs',
#  'attack',
#  'decided',
#  'chance',
#  'hero',
#  'fairly',
#  'reasons',
#  'voice',
#  'feeling',
#  'movies',
#  'allow',
#  'shot',
#  'third',
#  'boxes',
#  'weird',
#  'nes',
#  'purchase',
#  'compare',
#  'someone',
#  'rock',
#  'normal',
#  'words',
#  'ahead',
#  'shooters',
#  'driving',
#  'limited',
#  'songs',
#  'memorable',
#  'vs',
#  'admit',
#  'fighters',
#  'product',
#  'collecting',
#  'walk',
#  'needs',
#  'manny',
#  'whats',
#  'gem',
#  'appear',
#  'free',
#  'ships',
#  'complex',
#  'wall',
#  'fly',
#  'skills',
#  'certainly',
#  'links',
#  'worked',
#  'beaten',
#  'horrible',
#  'somewhat',
#  'ride',
#  'tedious',
#  'realism',
#  'test',
#  'cable',
#  'gone',
#  'formula',
#  'force',
#  'forget',
#  'reach',
#  'tv',
#  'possibly',
#  'beyond',
#  'space',
#  'market',
#  'starts',
#  'ten',
#  'likely',
#  'detailed',
#  'wait',
#  'mountain',
#  'spend',
#  'field',
#  'points',
#  'tag',
#  'era',
#  'challenges',
#  'crazy',
#  'temples',
#  'serious',
#  'journey',
#  'environment',
#  'direction',
#  'major',
#  'adds',
#  'aku',
#  'brilliant',
#  'gta',
#  'school',
#  'particular',
#  'perhaps',
#  'anymore',
#  'saturn',
#  'creative',
#  'sense',
#  'standards',
#  'spectacular',
#  'enter',
#  'giving',
#  'designed',
#  'ability',
#  'championship',
#  'confusing',
#  'quick',
#  'air',
#  'bunch',
#  'fights',
#  'overworld',
#  'offers',
#  'issues',
#  'supposed',
#  'filled',
#  'option',
#  'considering',
#  'horse',
#  'walking',
#  'higher',
#  'green',
#  'j',
#  'newer',
#  'hand',
#  'pack',
#  'glad',
#  'detail',
#  'build',
#  'plain',
#  'maps',
#  'became',
#  'ugly',
#  'known',
#  'average',
#  'john',
#  'aside',
#  'search',
#  'banjos',
#  'aspect',
#  'create',
#  'note',
#  'thanks',
#  'recent',
#  'managed',
#  'saying',
#  'store',
#  'understand',
#  'kokiri',
#  'felt',
#  'otherwise',
#  'reading',
#  'indeed',
#  'straight',
#  'children',
#  'score',
#  'triforce',
#  'says',
#  'finished',
#  'yeah',
#  'e',
#  'grim',
#  'witch',
#  'david',
#  'gruntilda',
#  'watch',
#  'key',
#  'notice',
#  'numerous',
#  'keeps',
#  'solve',
#  'r',
#  'switch',
#  'hell',
#  'map',
#  'smooth',
#  'entertainment',
#  'london',
#  'addition',
#  'scenery',
#  'seven',
#  'ultimate',
#  'plays',
#  'waste',
#  'overrated',
#  'blast',
#  'talking',
#  'keeping',
#  'legendary',
#  'animation',
#  'twice',
#  'hey',
#  'tons',
#  'rating',
#  'happens',
#  'helps',
#  'ryu',
#  'door',
#  'elements',
#  'thinking',
#  'check',
#  'required',
#  'remake',
#  'terrible',
#  'poor',
#  'load',
#  'robert',
#  'absolute',
#  'racers',
#  'addictive',
#  'addicting',
#  'step',
#  'nod',
#  'walls',
#  'colors',
#  'practice',
#  'opponent',
#  'taking',
#  'working',
#  'apart',
#  'tired',
#  'waiting',
#  'forces',
#  'physics',
#  'hardly',
#  'bowser',
#  'ace',
#  'alpha',
#  'strange',
#  'require',
#  'facility',
#  'happened',
#  'saw',
#  'download',
#  'period',
#  'yoshi',
#  'family',
#  'types',
#  'fairy',
#  'snow',
#  'completing',
#  'literally',
#  'writing',
#  'bof',
#  'art',
#  'musical',
#  'mentioned',
#  'drive',
#  'doubt',
#  'lose',
#  'includes',
#  'handle',
#  'fully',
#  'crystal',
#  ...]

# %%
#   -----------------------------------------------------------------
# get the similarity between two words
#   -----------------------------------------------------------------

print(model_cb.wv.similarity('zelda', 'heart'))
print(time.strftime("%H:%M:%S", time.gmtime()))
# Out:
# 0.8097283
# 21:52:56

# %%
# Experimentation with data structures
# Convert model.wv to a list of dictionaries


import pandas as pd

# Convert model.wv to a list of dictionaries
word_vectors = [{'word': word, 'vector': model_cb.wv[word]} for word in model_cb.wv.index_to_key]

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame.from_records(word_vectors)

# Print the DataFrame
print(df.head(n = 50))
# Out:
#               word                                             vector
# 0             game  [0.14726841, 0.2675027, 0.15350933, 0.18677944...
# 1          overall  [-0.41355503, 0.50909615, 0.06568519, 0.265697...
# 2          helpful  [0.6562877, 0.104419164, 0.44994003, 0.2843785...
# 3       reviewerid  [0.2581557, 0.23815838, 0.5039665, 0.39773974,...
# 4             asin  [0.39486924, 0.19696124, 0.59134626, 0.2907761...
# 5          summary  [-0.2557342, 0.41270193, 0.17242137, 0.4297283...
# 6       reviewtext  [0.49070364, 0.10820619, 0.3717794, 0.33909672...
# 7       reviewtime  [0.22230281, 0.3045503, 0.5091604, 0.445033, -...
# 8   unixreviewtime  [0.049603473, 0.28855324, 0.37950322, 0.320178...
# 9     reviewername  [0.5175663, 0.21741618, 0.5265212, 0.4151329, ...
# 10             one  [0.07360341, 0.29183272, 0.15452932, 0.1891607...
# 11           games  [0.13681239, 0.4731109, 0.21195054, 0.14671946...
# 12            time  [0.18521364, 0.3131428, 0.18284409, 0.1700498,...
# 13            like  [0.18755582, 0.47843522, 0.16518866, 0.1606081...
# 14             get  [0.1485661, 0.47017887, 0.13083425, 0.1547718,...
# 15           great  [-0.09546744, 0.3059341, 0.15251113, 0.2611469...
# 16            play  [0.20795114, 0.42478606, 0.19308154, 0.1714985...
# 17            good  [-0.05077958, 0.33904266, 0.12437565, 0.236771...
# 18            best  [0.019630115, 0.23898175, 0.120540895, 0.15217...
# 19             fun  [0.06475975, 0.31565455, 0.12891252, 0.1786360...
# 20           first  [0.18778431, 0.29801008, 0.20770675, 0.1643186...
# 21           zelda  [0.17936683, 0.42825848, 0.22510277, 0.1249820...
# 22        graphics  [0.015611586, 0.35664698, 0.1273282, 0.1737595...
# 23            even  [0.14099301, 0.4054266, 0.17165573, 0.13852176...
# 24          really  [0.17856283, 0.26752812, 0.18796827, 0.1654458...
# 25           still  [0.13078952, 0.3752003, 0.14265952, 0.1373114,...
# 26            also  [0.23856425, 0.6578631, 0.26432526, 0.16771956...
# 27            much  [0.16221325, 0.50776815, 0.22068495, 0.1848630...
# 28            ever  [0.17578931, 0.2460918, 0.19641873, 0.14241858...
# 29            dont  [0.15379676, 0.60420346, 0.16554604, 0.1498744...
# 30          played  [0.15491067, 0.2519411, 0.18081757, 0.13119541...
# 31            well  [-0.008869714, 0.27019784, 0.13775432, 0.17055...
# 32            many  [0.1887935, 0.34247974, 0.15089913, 0.15285845...
# 33          better  [0.045917764, 0.32528624, 0.14388244, 0.184912...
# 34          levels  [0.075065784, 0.17322081, 0.08476707, 0.056379...
# 35              go  [0.11641046, 0.39034957, 0.16301538, 0.1520981...
# 36            back  [0.1713903, 0.41483894, 0.17732649, 0.16565898...
# 37           mario  [0.026101453, 0.062239606, 0.024406474, 0.0145...
# 38           would  [0.16359952, 0.3955516, 0.056096572, 0.1412784...
# 39             way  [0.20264713, 0.4303916, 0.21650302, 0.15180944...
# 40      characters  [0.2146096, 0.6280857, 0.23220424, 0.15171237,...
# 41            find  [0.15869859, 0.5007329, 0.16825606, 0.22060497...
# 42         playing  [0.071994714, 0.17714679, 0.10818735, 0.145368...
# 43           story  [0.14824583, 0.38596117, 0.1795551, 0.15695931...
# 44             new  [0.16428031, 0.5275131, 0.23496136, 0.1402599,...
# 45           level  [0.17197387, 0.40044686, 0.18711558, 0.1182775...
# 46           world  [0.17744878, 0.37657183, 0.1900289, 0.1393463,...
# 47          series  [0.19153273, 0.5388107, 0.31680655, 0.11860492...
# 48            link  [0.00071804324, 0.00061711273, -0.003092227, 0...
# 49            make  [0.19116221, 0.4246279, 0.18036039, 0.17073953...

# %%
#   -----------------------------------------------------------------
# Training a Skip-gram model
#   -----------------------------------------------------------------

from gensim.models import Word2Vec

model_sg = Word2Vec([words], window=2, min_count=1, sg=1, vector_size=300, epochs=50)

# Print the most similar words
print(model_sg.wv.most_similar("king"))
# Out:
# [('diminishing', 0.9932238459587097), ('innovation', 0.9912392497062683), ('features', 0.9892754554748535), ('returns', 0.9883993864059448), ('addition', 0.9878091812133789), ('gorgeous', 0.9870482087135315), ('combination', 0.9869081377983093), ('gameif', 0.986084520816803), ('ego', 0.9857894778251648), ('obsession', 0.9851407408714294)]

# %%
# -----------------------------------------------------------------
# Finding the cosine distance between the word embeddings
# The cosine distance between two vectors is the cosine of the angle between the two vectors.
# The cosine distance is a measure of similarity between two vectors.
# The cosine distance ranges from -1 to 1.
# -----------------------------------------------------------------


from sklearn.metrics.pairwise import cosine_similarity

# Get the word embeddings for "america" from Skip-gram and CBOW models
embedding_sg = model_sg.wv["world"].reshape(1, -1)
embedding_cb = model_cb.wv["world"].reshape(1, -1)

# Calculate the cosine similarity between the two embeddings
cosine_distance = 1 - cosine_similarity(embedding_sg, embedding_cb)[0][0]

print("Cosine distance between Skip-gram and CBOW embeddings for 'world':", cosine_distance)
# Out:
# Cosine distance between Skip-gram and CBOW embeddings for 'world': 0.08574259281158447

# %% [markdown]
# ## GloVe: Global Vectors

# %%
# -----------------------------------------------------------------
# import glove model and print embeddings for a word
# 100 dimension model
# -----------------------------------------------------------------

from gensim.models import KeyedVectors


print(time.strftime("%H:%M:%S", time.gmtime()))

# -----------------------------------------------------------------
# # Load the GloVe model
# The key is to use the no_header parameter to indicate that the file does not contain a header
# This caused the model to load successfully and the embeddings to be accessible.
# -----------------------------------------------------------------
glove_model3_100 = KeyedVectors.load_word2vec_format('./glove.6B/glove.6B.100d.txt', binary=False, no_header=True)

print(time.strftime("%H:%M:%S", time.gmtime()))
#
# Out:
# 22:07:11
# 22:07:41

# %%
# -----------------------------------------------------------------
# 300 dimension model
# -----------------------------------------------------------------
print(time.strftime("%H:%M:%S", time.gmtime()))
glove_model3_300 = KeyedVectors.load_word2vec_format('./glove.6B/glove.6B.300d.txt', binary=False, no_header=True)
print(time.strftime("%H:%M:%S", time.gmtime()))
# Out:
# 22:08:03
# 22:09:14

# %%
# -----------------------------------------------------------------
# Print vocaublary size for both glove models
# -----------------------------------------------------------------
print(len(glove_model3_100.index_to_key))
print(len(glove_model3_300.index_to_key))
# Out:
# 400000
# 400000

# %%
# -----------------------------------------------------------------
# print embeddings for a word in glove_model3
# -----------------------------------------------------------------
# print(glove_model3['america'])

print(glove_model3_300['america'])

# # Print the most similar words
print(glove_model3_300.most_similar("king"))
# Out:
# [ 5.8489e-02 -2.5842e-01 -1.3714e-02 -1.2991e-01 -2.4317e-01  8.0817e-01
#  -7.3859e-01  6.8369e-01  3.5096e-02 -1.4020e+00  9.0090e-01  1.6326e-01
#   1.6109e-01 -2.7931e-01  2.1604e-01 -2.6137e-01  1.4417e-01 -2.6277e-01
#  -2.4252e-01  8.2353e-02 -6.2638e-02  3.7031e-01  6.5962e-01  2.3178e-01
#  -4.4202e-01 -1.8971e-01  2.1155e-01 -8.6515e-02 -1.1751e-01 -1.7021e-01
#  -4.3983e-02  5.4723e-01 -1.4636e-01 -4.0266e-01 -8.3730e-01  1.2009e-01
#  -7.8500e-02 -4.2377e-01 -2.0081e-01 -1.8051e-01 -5.1198e-02 -1.6930e-01
#  -1.3624e-01  4.8605e-01  8.1530e-02  6.3648e-02  3.1479e-01  2.3262e-01
#   1.1605e-01 -2.5602e-01  1.7535e-01  5.9225e-02  5.4992e-03  3.5402e-01
#  -4.2574e-01  1.0849e-01 -3.1691e-01 -2.0802e-01  1.2963e-01 -6.8191e-02
#   2.4378e-01 -2.4580e-02  9.8606e-02 -1.8751e-01 -2.9935e-01  4.0835e-01
#  -4.0737e-02  7.1439e-01  2.2632e-02 -2.0012e-02 -2.4854e-01  5.9211e-02
#  -1.2204e-01  7.5426e-02 -1.6433e-01 -7.0031e-02 -2.1207e-01  2.0083e-02
#  -3.9992e-01 -3.7857e-01 -3.9331e-01  2.3015e-01 -3.5663e-01  1.5155e-01
#  -2.3603e-01  5.5532e-02 -1.1886e-01 -1.7283e-01 -3.6305e-01 -3.9935e-01
#  -4.3175e-02 -7.4277e-01  6.8785e-02  3.1685e-02 -2.0839e-01 -3.7921e-01
#  -1.2483e-01  1.8009e-01  1.5888e-01 -3.7566e-01  3.4816e-01  2.3054e-01
#   1.2270e-03  3.0351e-01  2.9512e-01  1.7735e-03 -2.4432e-02  3.7263e-01
#   8.7557e-02  4.7301e-01 -2.4189e-01 -7.4619e-01 -1.4519e-01 -5.2139e-01
#  -1.7959e-01 -1.6369e-01  4.8172e-02 -3.0957e-02 -1.1701e-01  4.7290e-03
#  -2.0603e-02 -4.4686e-01 -7.2045e-02  2.0444e-01 -1.0543e-01  5.9240e-01
#  -4.2030e-01  9.9210e-02  1.0319e-02  3.2646e-02  8.2154e-02 -1.8496e-01
#   1.4047e-01 -9.9635e-02 -3.2260e-01  1.8407e-01 -3.8324e-01  1.8463e-01
#  -2.4488e-02  2.0849e-01 -2.5727e-01 -2.2520e-01 -8.5726e-02  4.7286e-01
#  -5.4521e-02  5.5318e-02 -2.1775e-01 -3.6056e-01 -2.9403e-01 -7.8766e-03
#   3.5117e-01  2.2399e-01  3.6074e-01 -1.0501e-01  2.3979e-01  3.7940e-02
#  -4.6936e-01  2.8546e-02  2.2664e-01 -3.9497e-01  4.2300e-01  2.2590e-01
#   1.0341e-01  5.3071e-01 -1.8564e-02 -1.3626e-01 -3.0719e-01  1.2886e-01
#   1.4108e-01 -3.8817e-02  2.6947e-01 -7.1936e-02 -1.0744e+00  6.2540e-01
#   1.0328e+00  1.1424e-01 -1.4079e-01  9.8811e-02  3.6417e-01  8.5422e-01
#   7.0222e-02 -2.7193e-01  3.5860e-01 -1.5023e-01  4.1030e-01 -4.6320e-01
#  -4.0498e-01  4.7335e-03 -3.2629e-01  3.9083e-02 -1.9030e-01  5.3478e-01
#   4.4279e-02 -1.8453e-01 -1.2556e-01  3.9451e-01  4.5549e-01 -5.6538e-01
#   6.3019e-02  2.1923e-01  1.4383e+00  2.8353e-01  7.9426e-02 -2.3905e-01
#   2.9352e-02  2.6962e-01  4.1272e-01  3.3401e-01 -4.5427e-01  6.5111e-02
#  -2.4945e-01  6.9249e-03 -4.5204e-02  6.3266e-02 -2.6958e-01  4.3130e-01
#  -1.0447e-01  7.5767e-02 -2.8334e-01  2.9405e-01  2.1698e-01  7.1639e-02
#  -8.7480e-02  7.7691e-02  3.9301e-01  4.2962e-01  3.4864e-01 -3.3869e-01
#  -2.3104e-01 -4.6833e-01 -4.7185e-01  1.1908e-01  6.8223e-02  5.0871e-01
#   9.1729e-02 -4.5089e-01  8.0747e-02  2.0443e-01  2.8032e-01 -4.1673e-01
#  -7.2876e-01  1.2308e-01  2.8130e-01 -3.0815e-01 -6.2093e-01 -5.7521e-01
#  -2.3917e-01 -2.3079e-01  6.3655e-01  4.0385e-01  5.1437e-01 -1.7961e-01
#  -7.0045e-01  9.4323e-01  1.2953e-01 -1.3348e-01 -3.4518e-01 -1.4549e-01
#   4.6002e-01 -2.2716e-01  3.6226e-01 -2.1207e-01  4.2832e-02  2.8666e-01
#   2.1220e-01  2.7605e-01 -1.8510e-01 -3.1967e-01 -3.5459e-01  4.2402e-01
#  -1.3940e-01 -2.8570e-01  7.5907e-02  1.9204e-02  4.1285e-01 -4.5584e-02
#  -1.4586e+00  2.4446e-01  1.0162e+00 -1.0256e-01 -4.5570e-01 -4.0930e-01
#  -5.9211e-02  1.4410e-01  1.6565e-01  2.3493e-01  1.6776e-01  2.5260e-01
#   1.4724e-01 -9.6267e-02  2.1782e-01 -5.0783e-02 -4.1376e-02  3.9886e-01
#   3.6146e-01  6.3213e-02  1.5873e-01  3.7675e-02 -4.0837e-01 -1.2147e-01]
# [('queen', 0.6336469054222107), ('prince', 0.6196622848510742), ('monarch', 0.5899620652198792), ('kingdom', 0.5791266560554504), ('throne', 0.5606487989425659), ('ii', 0.5562329292297363), ('iii', 0.5503199100494385), ('crown', 0.5224862694740295), ('reign', 0.5217353701591492), ('kings', 0.5066401958465576)]

# %% [markdown]
# ## Fasttext

# %%
print(time.strftime("%H:%M:%S", time.gmtime()))
# Load Fasttext model
from gensim.models import KeyedVectors

# Load the FastText model
fasttext_model = KeyedVectors.load_word2vec_format('/Users/p.mittal/Library/Mobile Documents/com~apple~CloudDocs/Roux/Courses/NLP/Data/Embeddings/Fasttext/cc.en.300.vec', binary=False)


# Print the word embedding for "america"
print(fasttext_model["america"])
print(time.strftime("%H:%M:%S", time.gmtime()))

# %%
# print the length of total words in the model
print(len(fasttext_model.index_to_key))

# print a list of 100 randomly chosen words in the model
import random
random_words = random.sample(fasttext_model.index_to_key, 100)
print(random_words)

# Print all subwords of diabetes in the model
subwords = [subword for subword in fasttext_model.index_to_key if 'diabetes' in subword]
print(subwords)

print(len(subwords))

# %%
# print the most similar words to a word using fasttext model
# limit to 5 most similar words
print(fasttext_model.most_similar("diabetes", topn=10))

# %%
# print dimensions of all the models to compare
print("word2vec model:", model_sg.wv['america'].shape)
print("glove model 300:", glove_model3_300['america'].shape)
print("fasttext model:", fasttext_model['america'].shape)

# %%
# Compare all of the above models using the word "diabetes"
# Get the word embeddings for "diabetes" from all models
embedding_glove_model3_300 = glove_model3_300["diabetes"].reshape(1, -1)
embedding_fasttext = fasttext_model["diabetes"].reshape(1, -1)
embedding_sg = model_sg.wv["diabetes"].reshape(1, -1)
embedding_cb = model_cb.wv["diabetes"].reshape(1, -1)

# # Calculate the cosine similarity between the embeddings
cosine_distance_glove_fasttext = 1 - cosine_similarity(embedding_glove_model3_300, embedding_fasttext)[0][0]
cosine_distance_sg_cb = 1 - cosine_similarity(embedding_sg, embedding_cb)[0][0]
cosine_distance_glove_sg = 1 - cosine_similarity(embedding_glove_model3_300, embedding_sg)[0][0]
cosine_distance_glove_cb = 1 - cosine_similarity(embedding_glove_model3_300, embedding_cb)[0][0]
cosine_distance_fasttext_sg = 1 - cosine_similarity(embedding_fasttext, embedding_sg)[0][0]
cosine_distance_fasttext_cb = 1 - cosine_similarity(embedding_fasttext, embedding_cb)[0][0]

print("Cosine distance between GloVe and FastText embeddings for 'diabetes':", cosine_distance_glove_fasttext)
print("Cosine distance between Skip-gram and CBOW embeddings for 'diabetes':", cosine_distance_sg_cb)
print("Cosine distance between GloVe and Skip-gram embeddings for 'diabetes':", cosine_distance_glove_sg)
print("Cosine distance between GloVe and CBOW embeddings for 'diabetes':", cosine_distance_glove_cb)
print("Cosine distance between FastText and Skip-gram embeddings for 'diabetes':", cosine_distance_fasttext_sg)
print("Cosine distance between FastText and CBOW embeddings for 'diabetes':", cosine_distance_fasttext_cb)


# Since the cosine distance is larger than 1 for some of the models, it is not a valid distance measure.
# let's normalize the embeddings and then calculate the cosine distance

# Normalize the embeddings
embedding_glove_model3_300_nm = embedding_glove_model3_300/ np.linalg.norm(embedding_glove_model3_300)
embedding_fasttext_nm = embedding_fasttext / np.linalg.norm(embedding_fasttext)
embedding_sg_nm = embedding_sg / np.linalg.norm(embedding_sg)
embedding_cb_nm = embedding_cb / np.linalg.norm(embedding_cb)


# # Calculate the cosine similarity between the embeddings
cosine_distance_glove_fasttext = 1 - cosine_similarity(embedding_glove_model3_300_nm, embedding_fasttext_nm)[0][0]
cosine_distance_sg_cb = 1 - cosine_similarity(embedding_sg_nm, embedding_cb_nm)[0][0]
cosine_distance_glove_sg = 1 - cosine_similarity(embedding_glove_model3_300_nm, embedding_sg_nm)[0][0]
cosine_distance_glove_cb = 1 - cosine_similarity(embedding_glove_model3_300_nm, embedding_cb_nm)[0][0]
cosine_distance_fasttext_sg = 1 - cosine_similarity(embedding_fasttext_nm, embedding_sg_nm)[0][0]
cosine_distance_fasttext_cb = 1 - cosine_similarity(embedding_fasttext_nm, embedding_cb_nm)[0][0]

print("Cosine distance between GloVe and FastText embeddings for 'diabetes':", cosine_distance_glove_fasttext)
print("Cosine distance between Skip-gram and CBOW embeddings for 'diabetes':", cosine_distance_sg_cb)
print("Cosine distance between GloVe and Skip-gram embeddings for 'diabetes':", cosine_distance_glove_sg)
print("Cosine distance between GloVe and CBOW embeddings for 'diabetes':", cosine_distance_glove_cb)
print("Cosine distance between FastText and Skip-gram embeddings for 'diabetes':", cosine_distance_fasttext_sg)
print("Cosine distance between FastText and CBOW embeddings for 'diabetes':", cosine_distance_fasttext_cb)

# %%
# Find the norm of the embeddings
print("Norm of GloVe model 300:", np.linalg.norm(embedding_glove_model3_300))
print("Norm of FastText model:", np.linalg.norm(embedding_fasttext))
print("Norm of Skip-gram model:", np.linalg.norm(embedding_sg))
print("Norm of CBOW model:", np.linalg.norm(embedding_cb))

print("Norm of GloVe model 300:", np.linalg.norm(embedding_glove_model3_300_nm))
print("Norm of FastText model:", np.linalg.norm(embedding_fasttext_nm))
print("Norm of Skip-gram model:", np.linalg.norm(embedding_sg_nm))
print("Norm of CBOW model:", np.linalg.norm(embedding_cb_nm))

# %%
# Extracting word vectors from the model glove_model3_300

# glove_model3_300.vectors.shape



# -------------------------
# Reducing dimensions to 3
# -------------------------

umap_model = UMAP(n_components=3)

glove_umap_embeddings = umap_model.fit_transform(glove_model3_300.vectors)

glove_umap_embeddings.shape

# %%
# print the first 5 rows of the embeddings
# print(glove_umap_embeddings[:5])

# 3d plot first 10000 words using plotly
import plotly.express as px

# Create a DataFrame with the UMAP embeddings and the words
df = pd.DataFrame(glove_umap_embeddings[:10000], columns=["x", "y", "z"])
df["word"] = glove_model3_300.index_to_key[:10000]

# Create a 3D scatter plot

fig = px.scatter_3d(df, x="x", y="y", z="z", text="word", title="UMAP 3D Embeddings")
fig.update_traces(textposition='top center')
fig.show()

# %% [markdown]
# ## Experimentation this point onward

# %%
# filename = '/Users/p.mittal/Library/Mobile Documents/com~apple~CloudDocs/Roux/Courses/NLP/Data/text8 Wikipedia/text8'

# def read_data(filename, char):
#     with open(filename, 'r') as f:
#         data = f.read(char)
#     return data


# text = read_data(filename, 100000)

# print(time.strftime("%H:%M:%S", time.gmtime()))

# len(text)

# print(time.strftime("%H:%M:%S", time.gmtime()))

# # split the text into words
# words = text.split()
# len(words)
# print(time.strftime("%H:%M:%S", time.gmtime()))

# # remove the punctuation
# import string
# table = str.maketrans('', '', string.punctuation)
# words = [w.translate(table) for w in words]
# print(len(words))
# print(time.strftime("%H:%M:%S", time.gmtime()))

# %%
# # Build subwords vocabulary using fasttext model
# from gensim.models import FastText

# # Train the FastText model
# fasttext_model = FastText([words], window=5, min_count=1, sg=1, vector_size=300, epochs=50)

# # Print the most similar words
# # print(fasttext_model.wv.most_similar("king"))

# # print the total voculabulary size including subwords
# print(len(fasttext_model.wv.index_to_key))


# # how many subwords are there for the word "diabetes"

# %%
# # print subwords in the model
# subwords = [subword for subword in fasttext_model.wv.index_to_key if 'anarchist' in subword]
# print(subwords)

# %%
# # create fasttext embeddings using the text file
# from gensim.models import FastText

# # # Train the FastText model
# model_ft = FastText([words], window=2, min_count=1, sg=1, vector_size=300, epochs=50)

# # # Print the most similar words
# # print(model_ft.wv.most_similar("king"))

# # # Get the word embeddings for "america" from FastText model
# # create fasttext embeddings using the text file
# # Train the FastText model
# model_ft = FastText(window=2, min_count=1, sg=1, vector_size=300, epochs=50)

# # Build the vocabulary with subwords
# model_ft.build_vocab(corpus_file='/path/to/your/text/file')

# # Train the model on the corpus
# model_ft.train(corpus_file='/path/to/your/text/file', total_examples=model_ft.corpus_count, epochs=model_ft.epochs)

# # Print the most similar words
# print(model_ft.wv.most_similar("king"))

# # Get the word embeddings for "america" from FastText model
# embedding_ft = model_ft.wv["america"].reshape(1, -1)

# # Calculate the cosine similarity between the embeddings
# cosine_distance = 1 - cosine_similarity(embedding_ft, embedding_glove_model3_300)[0][0]

# print("Cosine distance between FastText and GloVe embeddings for 'america':", cosine_distance)

# # embedding_ft = model_ft.wv["america"].reshape(1, -1)

# # # Calculate the cosine similarity between the embeddings
# # cosine_distance = 1 - cosine_similarity(embedding_ft, embedding_glove_model3_300)[0][0]

# # print("Cosine distance between FastText and GloVe embeddings for 'america':", cosine_distance)
